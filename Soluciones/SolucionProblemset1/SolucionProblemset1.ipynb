# %% [markdown]
# # Problema 1

# %% [markdown]
# ## 1.1

# %%
M = 5.9e27      # g
R = 6.4e8       # cm
G = 6.67e-8     # dyn*cm^2/g^2
d = 200         # cm
a = 2*G*M*d/R**3
print(f"a = {a:.4f} cm/s**2")
# Out:
# a = 0.0006 cm/s**2

# %% [markdown]
# ## 1.2

# %%
d = 1.28e9 # cm
a = 2*G*M*d/R**3
print(f"a = {a:.4f} cm/s**2")
# Out:
# a = 3843.0664 cm/s**2

# %% [markdown]
# ## 1.3.a

# %%
M = 1.9e33 # g
d = 200 # cm
R = 1e7  # cm
a = 2*G*M*d/R**3
print(f"a = {a:.4f} cm/s**2")
# Out:
# a = 50692000.0000 cm/s**2

# %% [markdown]
# ## 1.3.b

# %%
print(a/979)
# Out:
# 51779.36670071501

# %% [markdown]
# Sí, esta es igual a 51779 veces la aceleración de la gravedad, y un ser humano sería destrozado y espaghettificado

# %% [markdown]
# ## 1.4

# %%
M = 1.9e41
R = 2.95e13
a = 2*G*M*d/R**3
print(f"a = {a:.4f} cm/s**2")
# Out:
# a = 0.0002 cm/s**2

# %% [markdown]
# # 1.5

# %% [markdown]
# # Problema 2

# %%
import math

c = 2.9979e10    # Velocidad de la Luz (cm/s)
h = 6.6262e-27   # Constante de Planck (erg * s)
m = 9.1095e-28   # Masa del Electrón (g)
e = 4.80325e-10  # Carga del Electrón (esu)
G = 6.6732e-8    # Constante de Gravitación (dyn * cm^2 / g^2)
M = 1.6726e-24   # Masa del Protón (g)

def solve_problem_2():
    # 1. Constante de entropía de agujero negro [2]
    # Fórmula: c^3 / (2 * h * G)
    c1 = (c**3) / (2 * h * G)

    # 2. Constante de radiación gravitacional [2]
    # Fórmula: (32 * G^5) / (5 * c^10)
    c2 = (32 * (G**5)) / (5 * (c**10))

    # 3. Constante de Thomas-Fermi [2]
    # Fórmula: (324 / 175) * (4 / (9 * pi))^(2/3)
    c3 = (324 / 175) * (4 / (9 * math.pi))**(2/3)

    # 4. Sección transversal de dispersión de Thompson [2]
    # Fórmula: (8 * pi / 3) * (e^2 / (m * c^2))^2
    c4 = (8 * math.pi / 3) * ( (e**2) / (m * (c**2)) )**2

    # 5. Límite de Stark [2, 3]
    # Fórmula: (1 / M^5) * ( (4 * pi^2 * e^2 * m) / h^2 )^2
    c5 = (1 / (M**5)) * ( (4 * (math.pi**2) * (e**2) * m) / (h**2) )**2

    # 6. Constante de radiación de Bremstrahlung [3]
    # Fórmula: (32 * pi^2 * e^6) / (3 * sqrt(2 * pi * m^3) * c)
    c6 = (32 * (math.pi**2) * (e**6)) / (3 * math.sqrt(2 * math.pi * (m**3)) * c)

    # 7. Constante de Fotoionización [3]
    # Fórmula: (32 * pi^2 * e^6 * (2 * pi^2 * e^4 * m)) / (3^(3/2) * h^3)
    c7 = (32 * (math.pi**2) * (e**6) * (2 * (math.pi**2) * (e**4) * m)) / ((3**1.5) * (h**3))

    # Mostrar resultados con tres cifras significativas [2]
    print(f"1. Entropía de agujero negro: {c1:.2e}")
    print(f"2. Radiación gravitacional: {c2:.2e}")
    print(f"3. Thomas-Fermi: {c3:.2e}")
    print(f"4. Dispersión de Thompson: {c4:.2e}")
    print(f"5. Límite de Stark: {c5:.2e}")
    print(f"6. Radiación de Bremstrahlung: {c6:.2e}")
    print(f"7. Fotoionización: {c7:.2e}")

solve_problem_2()
# Out:
# 1. Entropía de agujero negro: 3.05e+64
# 2. Radiación gravitacional: 1.44e-140
# 3. Thomas-Fermi: 5.03e-01
# 4. Dispersión de Thompson: 6.65e-25
# 5. Límite de Stark: 2.73e+135
# 6. Radiación de Bremstrahlung: 6.26e-25
# 7. Fotoionización: 2.46e-39

# %% [markdown]
# # Problema 3

# %% [markdown]
# ## 3.1

# %% [markdown]
# $$F_g = F_c \Rightarrow m = \frac{R v^2}{G}$$
